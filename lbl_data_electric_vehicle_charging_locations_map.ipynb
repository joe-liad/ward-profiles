# %%
# %%capture
# !pip install keplergl

# %%
# %%capture
# !pip install geopandas mapclassify

# %%
import os

import geopandas as gpd
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
project_dir = '/content/gdrive/MyDrive/WardProfiles'
#oa_dir = f"{project_dir}/boundaries/oa"
#ward_dir = f"{project_dir}/boundaries/2022_wards"
ev_charg_loc_dir = f"{project_dir}/electric_vehicle_charging_locations"

# Outputs
out_dir = f"{project_dir}/electric_vehicle_charging_locations"

# %%
# !ls -lh "{ev_charg_loc_dir}"
# Out:
# total 76K
# -rw------- 1 root root 12K Jan  6 01:24 lb_lewisham.geojson
# -rw------- 1 root root 20K Jan  5 23:05 lewisham_electric_vehicle_charging_locations.csv
# -rw------- 1 root root 44K Jan  5 23:06 lewisham_electric_vehicle_charging_locations.geojson

# %% [markdown]
# Data
# --

# %%
df = pd.read_csv(f"{ev_charg_loc_dir}/lewisham_electric_vehicle_charging_locations.csv")
print(len(df))
df.head()
# Out:
# 86
#                         name  points  ...       lon        lat
# 0         MFG Stanstead Road     4.0  ... -0.044297  51.442382
# 1         MFG Stanstead Road     4.0  ... -0.044297  51.442382
# 2  Tesco Superstore-Lewisham     2.0  ... -0.012300  51.465958
# 3  Tesco Superstore-Lewisham     2.0  ... -0.012300  51.465958
# 4              Lidl-Lewisham     2.0  ... -0.005262  51.459996
#
# [5 rows x 13 columns]

# %%
# enable_custom_widget_manager/third-party Jupyter widgets
from google.colab import output
output.enable_custom_widget_manager()

# %%
from keplergl import KeplerGl
map_1=KeplerGl(height=600)
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(height=600)

# %%
map_1.add_data(data=df, name='Electric Vehicle Charging Locations in Lewisham')
map_1
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'layers': [{'config': {'dataId': 'Electric Vehicle C…

# %%
map_1.save_to_html(file_name="lewisham_ev_charging_locations.html")
# Out:
# Map saved to lewisham_ev_charging_locations.html!

# %% [markdown]
# carto link for the map
#
# https://kepler.gl/demo/map/carto?mapId=d98a0da7-5ae9-d57d-edef-60ab97afad6c&owner=miadp&privateMap=false
#
# dropbox link
#
# https://kepler.gl/demo/map?mapUrl=https://dl.dropboxusercontent.com/s/arj5eqqm8iivefv/keplergl_bagcjpt.json

# %%
# disable external widget
from google.colab import output
output.disable_custom_widget_manager()

# %% [markdown]
# Leaflet map
# --
